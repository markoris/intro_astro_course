# %%
from make_waveform import *
# Out:
# [Loading lalsimutils.py : MonteCarloMarginalization version]
#   scipy :  1.6.3
#   numpy :  1.20.3

# %%
## USERS EDIT THIS CELL ##

blackHole1_mass = 60 #Msolar
blackHole2_mass = 65 #Msolar
system_distance = 4500 #Mpc

# %%
bh1 = blackHole(blackHole1_mass, system_distance)
bh2 = blackHole(blackHole1_mass, system_distance)
binary = binaryBH(bh1, bh2)

params = binary.setParams(approx='IMRPhenomXHM')
binary.plotWaveform()
# Out:
# reading '/Users/kjwagner/intro_astro_course/theoretical/params.xml.gz' ...
# reading '/Users/kjwagner/intro_astro_course/theoretical/params.xml.gz' ...
# reading '/Users/kjwagner/intro_astro_course/theoretical/params.xml.gz' ...
# <Plot size 864x432 with 1 Axes>
